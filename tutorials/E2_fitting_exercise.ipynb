# %% [markdown]
# <a href="https://colab.research.google.com/github/gilIolgenblum/CrowdingModeWorkshop/blob/main/tutorials/E2_fitting_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 2: Fitting to Experimental Data
#
# This exercise tests your ability to load real experimental data, fit model parameters, assess fit quality, and estimate uncertainty.
#
# **System:** MET16 protein in TMAO solution.
# - **MET16:** SASA = 419.0 Å²
# - **TMAO:** ν = 3.98, χ = −0.74, χ_TS = −6.0
#
# Use the dataset: `app/sample_data/met16_tmao_binary_format1.csv`
#
# > *Tip: If running on Colab, set `DATA_PATH` to the raw GitHub URL of the CSV.*

# %%
# (Only needed on Colab — skip if running locally)
# !pip install git+https://github.com/gilIolgenblum/CrowdingModeWorkshop.git

# %%
import crowding as cr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ---
# ## Task B1 — Load and Inspect the Data
#
# **Steps:**
# 1. Load `met16_tmao_binary_format1.csv` using `pd.read_csv()`.
# 2. Print the first 5 rows and the number of data points.
# 3. Plot **ΔΔG⁰ vs concentration** (molal) as scatter points.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Task B2 — Fit eps to ΔΔG⁰
#
# **Steps:**
# 1. Create a `cr.Protein` (SASA=419.0) and a `cr.Cosolute` with the TMAO parameters.
# 2. Construct a `cr.CrowdingModel` — start with `eps=0.0`, `epsTS=0.0`, and `phiC_max=0.55`.
# 3. Fit `eps` to the experimental ΔΔG⁰ data using `model.fit_eps()`.
# 4. Print the fitted `eps` value.
#
# *Hint: Check tutorial 02 to see the calling convention for `fit_eps()`.*

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Task B3 — Fit epsTS and Plot
#
# **Steps:**
# 1. After fitting `eps`, also fit `epsTS` from the experimental ΔΔH⁰ data using `model.fit_epsTS()`.
# 2. Use `cr.Plotter` to plot the model prediction overlaid on the experimental data for all three quantities:
#    **ΔΔG⁰**, **ΔΔH⁰**, **TΔΔSi⁰**.
#
# *Hint: `cr.Plotter.plot_ddG()`, `plot_ddH()`, `plot_TddS()` each accept experimental data as arguments.*

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Task B4 — Evaluate Fit Quality (RMSE)
#
# The model produces a **continuous curve** over a fine φ grid. Your experimental data sits at discrete concentration points.
#
# **Steps:**
# 1. Convert the experimental **molal** concentrations to volume fraction φ using `model.molal` and `model.phiC` arrays (use `np.interp` to invert the mapping).
# 2. Interpolate the model's **ΔΔG⁰ curve** at the experimental φ values.
# 3. Compute the **Root Mean Squared Error (RMSE)** between the interpolated model and the experimental ΔΔG⁰.
# 4. Print the RMSE value.
#
# **Question (answer below):** Is the RMSE acceptable for biophysical data? What would you do if it were too large?

# %%
# YOUR CODE HERE

# %% [markdown]
# *✏️ Your answer:*

# %% [markdown]
# ---
# ## Task B5 — Uncertainty via Monte Carlo Subsampling
#
# **Steps:**
# 1. Define a fitting function that takes `(exp_conc, exp_ddG)` arrays and returns a fitted `eps` value.
#    *(Hint: build a fresh model inside the function, call `fit_eps()`, and return `model.eps`.)*
# 2. Pass this function to `cr.monte_carlo_subsampling()` — run **50 iterations**, retaining **80%** of data points.
# 3. Report the **mean** and **standard deviation** of the distribution of fitted `eps` values.

# %%
# YOUR CODE HERE
