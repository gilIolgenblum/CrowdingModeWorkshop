# %% [markdown]
# <a href="https://colab.research.google.com/github/gilIolgenblum/CrowdingModeWorkshop/blob/main/tutorials/E1_forward_simulation_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 1: Forward Simulation
#
# This exercise tests your understanding of the `crowding` package API for **forward (simulation) mode**.
# You will build models from scratch using new protein-cosolute pairs not seen in the tutorials.
#
# > **Note:** All cosolute parameters below are taken from published experimental measurements.
#
# Work through each task in order. Use what you learned in tutorials 01–03.

# %%
# (Only needed on Colab — skip if running locally)
# !pip install git+https://github.com/gilIolgenblum/CrowdingModeWorkshop.git

# %%
import crowding as cr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ---
# ## Task A1 — Build a Model from Scratch
#
# **System:** MET16 protein in TMAO solution.
#
# Parameters:
# - **MET16:** SASA = 419.0 Å²
# - **TMAO:** ν = 3.98, χ = −0.74, χ_TS = −6.0
# - Set **eps = 0**, **epsTS = 0** (no soft interaction for now)
# - Use `phiC_max=0.20` and `dphiC=0.001`
#
# **Steps:**
# 1. Create a `cr.Protein` and a `cr.Cosolute`.
# 2. Build and solve a `cr.CrowdingModel`.
# 3. Print the predicted **ΔΔG⁰** (in kJ/mol) at **φ = 0.10**.
#
# *Hint: `model.phiC` contains the volume fraction array and `model.ddA_kj` contains the ΔΔG⁰ array.*

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Task A2 — Compare Two Cosolutes
#
# **System:** MET16 in TMAO vs. MET16 in Glycerol.
#
# Glycerol parameters: ν = 2.479, χ = 0.610, χ_TS = −3.650
#
# **Steps:**
# 1. Reuse your TMAO model from Task A1.
# 2. Create a second `cr.CrowdingModel` for MET16 + Glycerol (same `eps=0`).
# 3. Plot **ΔΔG⁰ vs φ** for **both** cosolutes on the **same axes** with a legend.
#
# **Question (answer below):** Which cosolute stabilizes MET16 more at φ = 0.10?

# %%
# YOUR CODE HERE

# %% [markdown]
# *✏️ Your answer:*

# %% [markdown]
# ---
# ## Task A3 — Sensitivity to ν
#
# **System:** MET16 + Glycerol (from Task A2).
#
# **Steps:**
# 1. Create a second Glycerol model with **ν doubled to 5.0** (all other parameters unchanged).
# 2. On the **same figure**, plot two subplots:
#    - Left: ΔΔG⁰ for original (ν = 2.479) vs. doubled (ν = 5.0)
#    - Right: TΔΔSi⁰ for both models
#
# **Question (answer below):** Does ΔΔH⁰ change when you double ν? Why or why not?

# %%
# YOUR CODE HERE

# %% [markdown]
# *✏️ Your answer:*

# %% [markdown]
# ---
# ## Task A4 — Add a Soft Interaction
#
# **System:** MET16 + Glycerol, now with **eps = −0.5** and **epsTS = 0.3**.
#
# > **Reminder:** `eps` is the total soft interaction free energy, `epsTS` is its entropic component,
# > and `epsH = eps - epsTS` is the enthalpic component.
#
# **Steps:**
# 1. Build a new `cr.CrowdingModel` for MET16 + Glycerol with `eps=-0.5`, `epsTS=0.3`.
# 2. Use `cr.Plotter` to produce the full thermodynamic panel plot (ΔΔG⁰, ΔΔH⁰, TΔΔSi⁰).
#
# **Question (answer below):** What did adding `eps` change compared to the `eps=0` case in Task A2? Which thermodynamic component is affected?

# %%
# YOUR CODE HERE

# %% [markdown]
# *✏️ Your answer:*

# %% [markdown]
# ---
# ## Task A5 — Export Results to CSV
#
# **Steps:**
# 1. Export the results of your `eps=-0.5` Glycerol model (from Task A4) to a pandas DataFrame using `model.to_pandas()`.
# 2. Print the first 5 rows.
# 3. Save the DataFrame to a CSV file named `my_results.csv`.

# %%
# YOUR CODE HERE
